# %%
# ########################################################
# ################# JACKPOT TEMPLATE #####################
# ########################################################

import torch
import jackpot as jc
from time import time

# ------------------------------------
# DIRECT MODEL (TO BE COMPLETED BY USER)
# ------------------------------------

# Device & dtype setup
device = "cuda" if torch.cuda.is_available() else "cpu"
dtype = torch.float64
factory_kwargs = {"device": device, "dtype": dtype}
torch.manual_seed(0)

# Example: diagonal linear operator with shift
N = 1000
x_center = torch.randn((N,), **factory_kwargs)

A_diag = torch.ones(N, **factory_kwargs)
A_diag[0] = 1e-4
A_diag[1] = 1e-2

def Phi(x): 
    """Forward operator (replace with your own model)."""
    return A_diag * (x - x_center)

# Initial guess
x_est = x_center.clone()
# ------------------------------------


# ------------------------------------
# JACKPOT INITIALIZATION
# ------------------------------------
jack = jc.Jackpot(Phi, x_est)

# Experiment name
jack.set_experiment_name("jupyter_tuto")

# Load/save options
jack.sing_load = False
jack.sing_save = not jack.sing_load
jack.adv_mani_load = False
jack.adv_mani_save = not jack.adv_mani_load 
jack.save_plots = True

# Jacobian singular spectrum parameters
jack.n_sing = 10
jack.sing_max_time = 3600

# Adversarial manifold parameters
jack.n_dim = 2
jack.epsilon = 1e-1
jack.n_discr_pts = 21
jack.grid_lengths = 1.0
# ------------------------------------


# ------------------------------------
# JACOBIAN SINGULAR SPECTRUM
# ------------------------------------
if jack.sing_load:
    jack.jacobian_spectrum_load()
else:
    jack.jacobian_spectrum_compute()  # method="lobpcg" optional
    if jack.sing_save:
        jack.jacobian_spectrum_save()

# Plot spectrum
jack.jacobian_spectrum_plot()
# ------------------------------------


# ------------------------------------
# ADVERSARIAL MANIFOLD
# ------------------------------------
if jack.adv_mani_load:
    jack.adv_manifold_load()
else:
    jack.adv_manifold_compute()
    if jack.adv_mani_save:
        jack.manifold_save()

# Plot discrepancy
jack.plot_discrepancy(
    in_SNR=True,
    save_plot=jack.save_plots,
    levels=[20, 30, 40],
    color_levels=["g", "b", "r"],
)
# ------------------------------------
# Out:
# saves/jupyter_tuto/jupyter_tuto_singpairs_n_10.pth loaded.
# param| pos:[20,20,], iter: 0, loss: 5.000e-05, snr: -inf, grad: 0.000e+00: 100%|
# param| pos:[20,20,], iter: 0, loss: 5.000e-05, snr: -inf, grad: 4.843e-17: 100%|
# param| pos:[20,20,], iter: 0, loss: 5.000e-05, snr: -inf, grad: 0.000e+00: 100%|
# param| pos:[20,20,], iter: 0, loss: 5.000e-05, snr: -inf, grad: 0.000e+00: 100%|
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 82
#      75 # ------------------------------------
#      76
#      77
#      78 # ------------------------------------
#      79 # ADVERSARIAL MANIFOLD
#      80 # ------------------------------------
#      81 if jack.adv_mani_load:
# ---> 82     jack.adv_manifold_load()
#      83 else:
#      84     jack.adv_manifold_compute()
#
# File /mnt/data/These/identifying_the_non_identifiable/codes/jackpot_gitlab/src/jackpot/jackpot.py:552, in Jackpot.adv_manifold_load(self, n_dim, filename, filename_suffix)
#     550     print(f"There is no such file: {filename}.")
#     551 else:
# --> 552     self.adv_mani, self.grid = self._load_adv_mani_and_grid(self.Phi, filename)
#     553     print(f"{filename} loaded.")
#
# TypeError: Jackpot._load_adv_mani_and_grid() takes 2 positional arguments but 3 were given
